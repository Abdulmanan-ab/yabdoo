# %% [markdown]
# #### Question 1- A car with a full tank of gas drives 80 miles per hour for 3 hours before running out of gas. How many miles can the car go per tank?

# %% [markdown]
# ### Question 2- A runner travels a half marathon(13.1) in 3 hours. How fast was this runner going in miles per hour

# %% [markdown]
# *formular for Q 1= d*n where d=distance(in miles) and n=number of hours*

# %% [markdown]
# \\*Formula for Q 2= d/t where d=distance and t=time\\*

# %% [markdown]
# ## Checkbox List
# [] Completed
# [X] To complete

# %% [markdown]
# ![IMG-20220630-WA0034.jpg](attachment:IMG-20220630-WA0034.jpg)

# %%
speed = 80  # miles per hour
time = 3    # hours
distance = speed * time
print("the car can travel", distance, "miles before it runs out of gas")
# Out:
# the car can travel 240 miles before it runs out of gas

# %% [markdown]
# ##QUESTION 2

# %%
distance = 13.1 # in miles
time = 3 # in hours
speed = distance / time # in miles per hour
print("The runners speed was approximately", round(speed,2), 'miles per hour.')
# Out:
# The runners speed was approximately 4.37 miles per hour.

# %%
distance = 13.1 # in miles
time = 3 # in hours
speed = distance / time # in miles per hour
print("The runners speed was approximately", round(speed,2), 'miles per hour.')
# Out:
# 4.366666666666666

# %%
Y = X*(a^b)
y = # final number of infected
x = # initial number of people infected, 5
a = # number of people each infected person infects, 2
b = # number of rounds of infection ,5
y = 5*(2**5)
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_8292\34883999.py", line 2
#     y = # final number of infected
#         ^
# SyntaxError: invalid syntax

# %%
y =5*(2**5)
print (y)
# Out:
# 160

# %% [markdown]
# 160 people have been infected with the virus after 5 rounds of infection
